# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.sparse as sparse
import seaborn as sns

from math import log,exp,inf

from Bio.SeqFeature import FeatureLocation
from Bio.SeqRecord import SeqRecord
from Bio import SeqIO
from Bio.Seq import Seq
from plotting_functions import *
import pickle
import copy

# %%
import ast
im_info = pd.read_csv('../data/precise_1.0/precise1_im_info.csv')

IM_genes = {}
for i in range(len(im_info['im_name'])):
    IM_genes[im_info['im_name'][i]] = ast.literal_eval( im_info['genes'][i] )
IM_genes.keys()
# Out:
# dict_keys(['GlpR', 'DhaR/Mlc', 'ArgR', 'NarL', 'MalT', 'OxyR', 'Crp-2', 'AtoC', 'PurR-1', 'CsqR', 'MetJ', 'PurR-2', 'Cbl+CysB', 'GlcC', 'Crp-1', 'YiaJ', 'GcvA', 'XylR', 'RpoH', 'GadEWX', 'PrpR', 'GadWX', 'CecR', 'ArcA-1', 'Fnr', 'CdaR', 'Pyruvate', 'SrlR+GutM', 'NagC/TyrR', 'CpxR', 'Lrp', 'Leu/Ile', 'Fur-1', 'Thiamine', 'CysB', 'FliA', 'PuuR', 'NikR', 'NtrC+RpoN', 'RcsAB', 'His-tRNA', 'Fur-2', 'Copper', 'AllR/AraC/FucR', 'Cra', 'ArcA-2', 'EvgA', 'Zinc', 'SoxS', 'Nac', 'Tryptophan', 'FadR/IclR', 'FlhDC', 'GntR/TyrR', 'RpoS', 'ExuR/FucR', 'FecI', 'RbsR'])

# %%
Lrp_features = pd.read_csv('data/Lrp_features.csv',index_col=0)

Lrp_features_large = pd.read_csv('data/Lrp_features_large.csv', index_col=0)

# %%
import pickle
with open('data/Lrp_IM_motif_pal.pkl', 'rb') as f:
    val_scores_pal = pickle.load(f)
with open('data/Lrp_IM_motif.pkl', 'rb') as f:
    val_scores = pickle.load(f)
with open('data/Lrp_IM_motif_split_pal.pkl', 'rb') as f:
    val_scores_split = pickle.load(f)

# %%
val_scores_pal[('b0077','b0078')]
# Out:
# [[-12021,
#   -9674,
#   -11736,
#   -15291,
#   -10503,
#   -8919,
#   -12144,
#   -13195,
#   -12825,
#   -11829,
#   -9740,
#   -10590,
#   -7532,
#   -14002,
#   -7760,
#   -11315,
#   -11898,
#   -12835,
#   -11588,
#   -7726,
#   -9918,
#   -5595,
#   -12913,
#   -11927,
#   -12048,
#   -9872,
#   -11057,
#   -14808,
#   -8760,
#   -11897,
#   -13095,
#   -9472,
#   -16265,
#   -14001,
#   -10715,
#   -9967,
#   -10830,
#   -11597,
#   -8222,
#   -9967,
#   -11090,
#   -12838,
#   -14244,
#   -11081,
#   -10781,
#   -12711,
#   -7910,
#   -11921,
#   -7583,
#   -12812,
#   -12346,
#   -10564,
#   -12819,
#   -11712,
#   -14161,
#   -14159,
#   -13726,
#   -13901,
#   -10697,
#   -13394,
#   -14867,
#   -6599,
#   -10797,
#   -9730,
#   -11819,
#   -13069,
#   -13110,
#   -11921,
#   -12020,
#   -7901,
#   -11786,
#   -5251,
#   -9964,
#   -9048,
#   -9779,
#   -11819,
#   -10980,
#   -12078,
#   -9949,
#   -12827,
#   -9656,
#   -6453,
#   -9756,
#   -7576,
#   -10971,
# ...

# %% [markdown]
# ## ilvI
#
# - regulon motif better than any IM motif in this case. Why?
#
# ![image.png](attachment:image.png)

# %%
fig1 = plot_distr(gene_ID=('b0077', 'b0078'), true_sites=[-3,-23,-52,-87], split_motif=True, best_n=5, the_n_promt=1, val_scores=val_scores_split)

fig2= plot_distr(gene_ID=('b0077', 'b0078'), true_sites=[-3,-23,-52,-87], split_motif=False, best_n=5, the_n_promt=1, val_scores=val_scores_pal)


fig3 = plot_distr(gene_ID=('b0077', 'b0078'), true_sites=[-3,-23,-52,-87], split_motif=False, best_n=5, the_n_promt=1, val_scores=val_scores)

fig4 = plot_reg_distr(gene_ID='b0077', true_sites=[-3,-23,-52,-87], best_n=5, the_n_promt=2, distr_df=Lrp_features_large)

# %%
# averaging regulon

fig4 = plot_reg_distr(gene_ID='b0077', true_sites=[-3,-23,-52,-87], best_n=5, the_n_promt=0, distr_df=Lrp_features)

# %% [markdown]
# ## dadA
#
# ![image-2.png](attachment:image-2.png)

# %%
fig1 = plot_distr(gene_ID=('b1189', 'b1190'), true_sites=[19,-14,-59,-97,-127], split_motif=True, best_n=5, the_n_promt=0, val_scores=val_scores_split)

fig2= plot_distr(gene_ID=('b1189', 'b1190'), true_sites=[19,-14,-59,-97,-127], split_motif=False, best_n=5, the_n_promt=0, val_scores=val_scores_pal)


fig3 = plot_distr(gene_ID=('b1189', 'b1190'), true_sites=[19,-14,-59,-97,-127], split_motif=False, best_n=5, the_n_promt=0, val_scores=val_scores)

fig4 = plot_reg_distr(gene_ID='b1189', true_sites=[19,-14,-59,-97,-127], best_n=5, the_n_promt=1, distr_df=Lrp_features_large)

# %% [markdown]
# ## leuE

# %%
fig1 = plot_distr(gene_ID=('b1798',), true_sites=[-1,-35,-68], split_motif=True, best_n=5, the_n_promt=0, val_scores=val_scores_split)

fig2= plot_distr(gene_ID=('b1798',), true_sites=[-1,-35,-68], split_motif=False, best_n=5, the_n_promt=0, val_scores=val_scores_pal)


fig3 = plot_distr(gene_ID=('b1798',), true_sites=[-1,-35,-68], split_motif=False, best_n=5, the_n_promt=0, val_scores=val_scores)

fig4 = plot_reg_distr(gene_ID='b1798', true_sites=[-1,-35,-68], best_n=5, the_n_promt=0, distr_df=Lrp_features_large)

# %% [markdown]
# ## stpA
#
# ![image.png](attachment:image.png)

# %%
fig1 = plot_distr(gene_ID=('b2669',), true_sites=[-107], split_motif=True, best_n=5, the_n_promt=0, val_scores=val_scores_split)

fig2= plot_distr(gene_ID=('b2669',), true_sites=[-107], split_motif=False, best_n=5, the_n_promt=0, val_scores=val_scores_pal)


fig3 = plot_distr(gene_ID=('b2669',), true_sites=[-107], split_motif=False, best_n=5, the_n_promt=0, val_scores=val_scores)

fig4 = plot_reg_distr(gene_ID='b2669', true_sites=[-107], best_n=5, the_n_promt=1, distr_df=Lrp_features_large)

# %% [markdown]
# ## livJ
#
# ![image.png](attachment:image.png)

# %%
fig1 = plot_distr(gene_ID=('b3460',), true_sites=[-132], split_motif=True, best_n=5, the_n_promt=0, val_scores=val_scores_split)

fig2= plot_distr(gene_ID=('b3460',), true_sites=[-132], split_motif=False, best_n=5, the_n_promt=0, val_scores=val_scores_pal)


fig3 = plot_distr(gene_ID=('b3460',), true_sites=[-132], split_motif=False, best_n=5, the_n_promt=0, val_scores=val_scores)

fig4 = plot_reg_distr(gene_ID='b3460', true_sites=[-132], best_n=5, the_n_promt=0, distr_df=Lrp_features_large)

# %% [markdown]
# ## tdh
#
# ![image.png](attachment:image.png)

# %%
fig1 = plot_distr(gene_ID=('b3616','b3617'), true_sites=[-73, -84], split_motif=True, best_n=5, the_n_promt=0, val_scores=val_scores_split)

fig2= plot_distr(gene_ID=('b3616','b3617'), true_sites=[-73, -84], split_motif=False, best_n=5, the_n_promt=0, val_scores=val_scores_pal)


fig3 = plot_distr(gene_ID=('b3616','b3617'), true_sites=[-73, -84], split_motif=False, best_n=5, the_n_promt=0, val_scores=val_scores)

fig4 = plot_reg_distr(gene_ID='b3616', true_sites=[-73, -84], best_n=5, the_n_promt=0, distr_df=Lrp_features_large)

# %% [markdown]
# ## lysU
#
# ![image.png](attachment:image.png)

# %%
fig1 = plot_distr(gene_ID=('b4129',), true_sites=[-65], split_motif=True, best_n=5, the_n_promt=0, val_scores=val_scores_split)

fig2= plot_distr(gene_ID=('b4129',), true_sites=[-65], split_motif=False, best_n=5, the_n_promt=0, val_scores=val_scores_pal)


fig3 = plot_distr(gene_ID=('b4129',), true_sites=[-65], split_motif=False, best_n=5, the_n_promt=0, val_scores=val_scores)

fig4 = plot_reg_distr(gene_ID='b4129', true_sites=[-65], best_n=5, the_n_promt=0, distr_df=Lrp_features_large)
